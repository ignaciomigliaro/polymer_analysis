# %% [markdown]
# # Data analysis for polymer upcycling

# %% [markdown]
# This notebook uses the Gromacs built-in functions to analyze trajectories and observer properties such as SASA, RDF, rg, end-to-end distance, RMSD

# %% [markdown]
# ## Imports

# %%
import sys

sys.path.append("/data/polymer_upcycling/polymer_analysis/scripts")
import polyplots as pp

# %% [markdown]
# ## Run this if you want to refresh the script

# %%
import importlib, polyplots
importlib.reload(polyplots)
import polyplots as pp

# %% [markdown]
# ## RMSD

# %% [markdown]
# ### KDE

# %% [markdown]
# #### 1-4-DCB

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


fig, axes = pp.plot_superplot_rmsdist(
    BASE,
    carbons=CARBONS,
    funcs=FUNCS,
    runs=RUNS,
    ncols=3,
    mode="kde",
    kde_mode="mean",   # or "runs"
    savepath=Path("superplots") / f"SUPERPLOT_RMSDIST_{SOLVENT}_KDE.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RMSDIST_1-4-DCB_KDE.png

# %% [markdown]
# #### 1-2-DCB

# %%
SOLVENT = "1-2-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


# fig, axes = pp.plot_superplot_rmsdist(
#     BASE,
#     carbons=CARBONS,
#     funcs=FUNCS,
#     runs=RUNS,
#     ncols=3,
#     mode="kde",
#     kde_mode="mean",   # or "runs"
#     savepath=Path("superplots") / f"SUPERPLOT_RMSDIST_{SOLVENT}_KDE.png",
# )

# %% [markdown]
# ### Time

# %% [markdown]
# #### 1-4-DCB

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


fig, axes = pp.plot_superplot_rmsdist(
    BASE,
    carbons=CARBONS,
    funcs=FUNCS,
    runs=RUNS,
    ncols=3,
    mode="time",
    kde_mode="mean",   # or "runs"
    savepath=Path("superplots") / f"SUPERPLOT_RMSDIST_{SOLVENT}_KDE.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RMSDIST_1-4-DCB_KDE.png

# %% [markdown]
# #### 1-2-DCB

# %%
SOLVENT = "1-2-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


# fig, axes = pp.plot_superplot_rmsdist(
#     BASE,
#     carbons=CARBONS,
#     funcs=FUNCS,
#     runs=RUNS,
#     ncols=3,
#     mode="time",
#     kde_mode="mean",   # or "runs"
#     savepath=Path("superplots") / f"SUPERPLOT_RMSDIST_{SOLVENT}_KDE.png",
# )

# %% [markdown]
# ## RDF

# %% [markdown]
# ### RDF of C to COM of DCB

# %% [markdown]
# #### 1-4-DCB

# %%
from pathlib import Path
import importlib, polyplots
importlib.reload(polyplots)
import polyplots as pp

SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS   = [0, 10, 20]
RUNS    = [1, 2, 3]

fig, axes = pp.plot_superplot_rdf(
    base=BASE,
    solvent=SOLVENT,
    carbons=CARBONS,
    funcs=FUNCS,
    runs=RUNS,
    outpath=Path("superplots") / f"SUPERPLOT_RDF_{SOLVENT}.png",  # set None if you don't want to save
    ncols=3,
    thin_runs=False,   # True = thin each run + thick mean; False = only thick mean
    verbose=True,
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RDF_1-4-DCB.png

# %% [markdown]
# ## SASA

# %% [markdown]
# ## End-to-End

# %% [markdown]
# ### KDE

# %% [markdown]
# #### 1-4-DCB

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]

fig, axes = pp.superplot_polystat_by_carbon(
    base=BASE,
    solvent=SOLVENT,
    metric="ete",
    carbons=CARBONS,
    funcs=FUNCS,
    mode="kde",
    runs=RUNS,
    ncols=3,
    kde_orientation="vertical",
    thin_runs=False,
    outpath=Path("superplots") / f"SUPERPLOT_ETE_{SOLVENT}_kde.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_ETE_1-4-DCB_kde.png

# %% [markdown]
# ### Time

# %% [markdown]
# #### 1-4-DCB

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]

fig, axes = pp.superplot_polystat_by_carbon(
    base=BASE,
    solvent=SOLVENT,
    metric="ete",
    carbons=CARBONS,
    funcs=FUNCS,
    mode="time",
    runs=RUNS,
    ncols=3,
    thin_runs=False,
    outpath=Path("superplots") / f"SUPERPLOT_RG_{SOLVENT}.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RG_1-4-DCB.png

# %% [markdown]
# ## Rg

# %% [markdown]
# ### KDE

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]

fig, axes = pp.superplot_polystat_by_carbon(
    base=BASE,
    solvent=SOLVENT,
    metric="rg",
    carbons=CARBONS,
    funcs=FUNCS,
    mode="kde",
    kde_orientation="vertical",
    runs=RUNS,
    ncols=3,
    thin_runs=False,
    outpath=Path("superplots") / f"SUPERPLOT_RG_{SOLVENT}.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RG_1-4-DCB.png

# %% [markdown]
# ### Time

# %% [markdown]
# #### 1-4-DCB

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


fig, axes = pp.superplot_polystat_by_carbon(
    base=BASE, solvent=SOLVENT, 
    metric="rg",
    carbons=CARBONS, 
    funcs=FUNCS,
    runs=RUNS,
    mode="time", 
    thin_runs=False,
    outpath=Path("superplots") / f"SUPERPLOT_RG_{SOLVENT}_TIME.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RG_1-4-DCB_TIME.png

# %% [markdown]
# ## Persistent

# %% [markdown]
# ### 1-4-DCB

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


fig, axes = pp.superplot_polystat_by_carbon(
    base=BASE,
    solvent=SOLVENT,
    metric="persist",
    carbons=CARBONS,
    funcs=FUNCS,
    mode="time",
    runs=RUNS,
    ncols=3,
    thin_runs=False,
    outpath=Path("superplots") / f"SUPERPLOT_RG_{SOLVENT}.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_RG_1-4-DCB.png

# %%
SOLVENT = "1-4-DCB"
BASE = Path(f"/data/polymer_upcycling/all_data/{SOLVENT}")

CARBONS = [6, 20, 40, 60, 80, 200]
FUNCS = [0, 10, 20]
RUNS = [1, 2, 3]


fig, axes = pp.superplot_polystat_by_carbon(
    base=BASE,
    solvent=SOLVENT,
    metric="persist",
    carbons=CARBONS,
    funcs=FUNCS,
    mode="kde",
    kde_orientation="vertical",
    runs=RUNS,
    ncols=3,
    thin_runs=False,
    outpath=Path("superplots") / f"SUPERPLOT_PERSIST_{SOLVENT}_kde.png",
)
# Out:
# [OK] Saved superplots/SUPERPLOT_PERSIST_1-4-DCB_kde.png
